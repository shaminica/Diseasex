# %%
from binAd import isTrue, isProvable

# %% [markdown]
# ### 16.4(柳本)
# **問:** BinAd の “10+1=11” の機械証明を示せ.
# - 証明可能な命題 1: $1=1$ (公理)
# - 証明可能な命題 2: $1+1=1+1$ (証明可能な命題1に規則1を適用)
# - 証明可能な命題 3: $1+1+1=1+1+1$ (証明可能な命題2に規則1を適用)
# - 証明可能な命題 4: $1+1+1=1+10$ (証明可能な命題3に規則2を適用)
# - 証明可能な命題 5: $1+1+1=11$ (証明可能な命題4に規則3を適用)
# - 証明可能な命題 6: $10+1=11$ (証明可能な命題5に規則2を適用)

# %% [markdown]
# ### 16.9(柳本)
# **問:** BinAdLogic に整合性が取れていることを証明せよ.<br>
# *ヒント*: すべての推論規則が真の命題を真の命題に写像することを示せ
#
# BindAdLogicの真理値割り当ては, 命題が2進数の加算と解釈し両辺が等しい場合の時に限り, 真となる.2進数と加算の定義から、BindAdLogicの推論規則が真の命題を真の命題に写像するのは自明.

# %% [markdown]
# ### 16.14 (柳本)
# **問:** 「プログラム$P$は実行に多項式時間かかる」という命題をペアノ算術に翻訳する方法を説明せよ.
#
# 入力$I$が与えられたテープの初期状態のチューリングマシンを表す整数を$m_0$とする. $P$をシミュレーションしたときの遷移関数を$Step$とした時,$N$ステップ終了後のチューリングマシンの構成は$Step^N(m_0)$である.
#
# ここで、入力として整数$m$をとり、それが出力"yes"を表すなら1を, そうでなければ0を出力する関数を$isYes$とする. $Step$も$isYes$もペアノ算術で記述できるので(初歩的な算術演算を表現できるとした仮定),
#
# $$isYes(Step^N(m_0)) = 1$となるような整数$N$が存在する.
#
# という命題はペアノ算術で記述できる.

# %% [markdown]
# ### 16.19 (柳本)
# #### (a)
# 人間が適用できる推論規則もペアノ算術に基づいているため, コンピュータに証明できない命題は, 人間であっても証明できない.
#
# #### (b)
# TURING, A. M. “I.—COMPUTING MACHINERY AND INTELLIGENCE.” Mind LIX, no. 236 (October 1, 1950): 433–60. https://doi.org/10.1093/mind/LIX.236.433.
#
# - ゲーデルの不完全性定理は, コンピュータの限界を証明しただけで, 人間の限界に関しては何も証明していない
# - しかし, 答えられない問に対しコンピュータが答えを返したとしたら, 確実にコンピュータが間違いを犯したことはわかるので, ある種の優越感を人間は感じるだろう
# - しかし, これもまた, この失敗をした"あるコンピュータ"に対しての勝利であって, 全てのコンピュータに対する勝利ではない
#
# **意見**
# 以下の点において、賛成である.
# - そもそも、人間の優位性を示していない.
# - 1950年以降の人類の発展の大部分は、コンピュータの成長と言っても過言ではない. 人間の優位性が示されたところで、優越感以外に得られる物がない.
