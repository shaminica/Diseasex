# %% [markdown]
# ## 8.4
#
# ### (a)
#  - "yes"
#
# ### (b)
#  - 未定義

# %% [markdown]
# ## 8.9
#
# ### (a)
#  - $q_0, q_4$.
#
# ### (b)
#  - 入力"CGAT"とした時の計算木は下図.
#  - クローン総数：6個（root含む)
#  - 出力："yes"
#
# ### (c)
#  - 受理する入力の例: "CT", "CCCCCCCCT", "CGA"
#  - 拒絶する入力の例: "A", "CGT"
#  - 出力が未定義となる入力の例: "CA"
#
# ### (d)
# - 最初が"C"でない場合, クローンが作られることはなくすぐ拒絶. (クローン総数1)
# - 最初が"C"ならクローンは3つ作られるが, q_1,q_3に進むクローンはさらにクローンを作ることはない. (+3)
# - 最初が"C"で次が"G"なら, q_4に進んだクローンがさらにクローンを2つ作るが, どちらもさらにクローンを作ることはない. (+2)
# - したがってクローン総数(root含む)は最大で6なので, クローン総数は常に有限.

# %%
from IPython.display import Image
Image('image_8_9b.png')
